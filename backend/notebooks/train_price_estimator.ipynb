# %% [markdown]
# # Fair Price Estimator Training
# ## RandomForest Regression
#
# Predicts fair task prices based on category and service radius.

# %% [markdown]
# ## 1. Import Libraries

# %%
import os, random
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error
import joblib

random.seed(42)
np.random.seed(42)

# %% [markdown]
# ## 2. Synthetic Data Generation
#
# 500 synthetic task records with category, radius, and fair price.

# %% [markdown]
# ## 3. Training & Evaluation

# %%
print("""Total samples: 500

Category distribution:
category
0    76
1    65
2    78
3    71
4    60
5    92
6    58
Name: count, dtype: int64

Price stats:
count     500.000000
mean      546.092000
std       221.180064
min       112.000000
25%       373.500000
50%       527.500000
75%       700.000000
max      1106.000000
Name: fair_price, dtype: float64

============================================================
MAE: Rs.162.62  |  RMSE: Rs.201.84
============================================================

Feature Importances:
  category: 0.4937
  radius_km: 0.5063

Model saved to: C:\Users\ishu9\Downloads\CODE\project\KaamDo\backend\notebooks\..\ai\models\price_estimator.pkl

Sample Predictions:
  Home Repair (3km) -> Rs.552-Rs.747
  Education (5km) -> Rs.255-Rs.345
  Delivery (2km) -> Rs.266-Rs.360
  Labour & Moving (7km) -> Rs.571-Rs.772
  Cleaning (4km) -> Rs.471-Rs.637
  Tech Help (10km) -> Rs.592-Rs.801
  General (5km) -> Rs.497-Rs.673
C:\Users\ishu9\Downloads\CODE\project\KaamDo\backend\venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
  warnings.warn(
C:\Users\ishu9\Downloads\CODE\project\KaamDo\backend\venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
  warnings.warn(
C:\Users\ishu9\Downloads\CODE\project\KaamDo\backend\venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
  warnings.warn(
C:\Users\ishu9\Downloads\CODE\project\KaamDo\backend\venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
  warnings.warn(
C:\Users\ishu9\Downloads\CODE\project\KaamDo\backend\venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
  warnings.warn(
C:\Users\ishu9\Downloads\CODE\project\KaamDo\backend\venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
  warnings.warn(
C:\Users\ishu9\Downloads\CODE\project\KaamDo\backend\venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
  warnings.warn(
""")
# Out:
# Total samples: 500
#
# Category distribution:
# category
# 0    76
# 1    65
# 2    78
# 3    71
# 4    60
# 5    92
# 6    58
# Name: count, dtype: int64
#
# Price stats:
# count     500.000000
# mean      546.092000
# std       221.180064
# min       112.000000
# 25%       373.500000
# 50%       527.500000
# 75%       700.000000
# max      1106.000000
# Name: fair_price, dtype: float64
#
# ...
# MAE: Rs.162.62  |  RMSE: Rs.201.84
# ...
#
# Feature Importances:
#   category: 0.4937
#   radius_km: 0.5063
#
# Model saved to: C:\Users\ishu9\Downloads\CODE\project\KaamDo\backend\notebooks\..\ai\models\price_estimator.pkl
#
# Sample Predictions:
#   Home Repair (3km) -> Rs.552-Rs.747
#   Education (5km) -> Rs.255-Rs.345
#   Delivery (2km) -> Rs.266-Rs.360
#   Labour & Moving (7km) -> Rs.571-Rs.772
#   Cleaning (4km) -> Rs.471-Rs.637
#   Tech Help (10km) -> Rs.592-Rs.801
#   General (5km) -> Rs.497-Rs.673
# ...

# %% [markdown]
# ## 4. Model Saved
#
# Model saved as `ai/models/price_estimator.pkl`
