# %% [markdown]
# # Fair Price Estimator Training
# ## RandomForest Regression
#
# Predicts fair task prices based on category and service radius.

# %% [markdown]
# ## 1. Import Libraries

# %%
import os, random
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error
import joblib

random.seed(42)
np.random.seed(42)

# %% [markdown]
# ## 2. Synthetic Data Generation
#
# 500 synthetic task records with category, radius, and fair price.

# %% [markdown]
# ## 3. Training & Evaluation

# %%
print("""Traceback (most recent call last):
  File "C:\Users\ishu9\Downloads\CODE\project\KaamDo\backend\notebooks\train_price_estimator.py", line 8, in <module>
    import numpy as np
ModuleNotFoundError: No module named 'numpy'
""")
# Out:
# Traceback (most recent call last):
#   File "C:\Users\ishu9\Downloads\CODE\project\KaamDo\backend\notebooks\train_price_estimator.py", line 8, in <module>
#     import numpy as np
# ModuleNotFoundError: No module named 'numpy'

# %% [markdown]
# ## 4. Model Saved
#
# Model saved as `ai/models/price_estimator.pkl`
