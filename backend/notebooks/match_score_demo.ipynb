# %% [markdown]
# # Worker Match Score Demo
# ## Weighted Ranking Formula
#
# Demonstrates how workers are ranked for task matching.

# %% [markdown]
# ## Formula
#
# ```
# score = category_match * 0.40 + rating * 0.30 + proximity * 0.20 + experience * 0.10
# ```

# %% [markdown]
# ## Demo with 5 Workers

# %%
print("""======================================================================
WORKER MATCH SCORE DEMO
Task: 'home repair' at (12.9716, 77.5946), radius 5km
======================================================================

Rank  Name      Score   Distance  Rating  Tasks   Skills
----------------------------------------------------------------------
1     Rahul     91.2    0.53km    4.8     45      home repair, plumbing
2     Deepak    80.2    4.19km    4.5     100     labour & moving, home repair
3     Priya     78.2    2.04km    4.2     12      cleaning, home repair
4     Sunita    67.1    3.59km    3.5     5       home repair
5     Amit      61.8    1.91km    4.9     80      tech help, education

Formula: score = category_match*0.40 + rating*0.30 + proximity*0.20 + experience*0.10
Best match: Rahul with score 91.2
""")
# Out:
# ...
# WORKER MATCH SCORE DEMO
# Task: 'home repair' at (12.9716, 77.5946), radius 5km
# ...
#
# Rank  Name      Score   Distance  Rating  Tasks   Skills
# ----------------------------------------------------------------------
# 1     Rahul     91.2    0.53km    4.8     45      home repair, plumbing
# 2     Deepak    80.2    4.19km    4.5     100     labour & moving, home repair
# 3     Priya     78.2    2.04km    4.2     12      cleaning, home repair
# 4     Sunita    67.1    3.59km    3.5     5       home repair
# 5     Amit      61.8    1.91km    4.9     80      tech help, education
#
# Formula: score = category_match*0.40 + rating*0.30 + proximity*0.20 + experience*0.10
# Best match: Rahul with score 91.2

# %% [markdown]
# ## Conclusion
#
# Rahul scores highest (91.2) due to exact skill match, high rating, and close proximity.
